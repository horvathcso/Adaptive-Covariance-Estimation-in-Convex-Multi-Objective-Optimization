# %%
# %pip install pymoo scipy pandas scikit-learn matplotlib

# %% [markdown]
# ## Creating the Dataset for Training a Surrogate Model
#
# ### Objective
#  The aim is to create a dataset to train a surrogate model that learns the relationship between the user preference vector (λ) and the local variability of optimal solutions, measured using the Frobenius norm of the estimated covariance matrix (∥Ĉ(λ)∥_F).
#
# In practical terms, the goal is:
#
# $$ \lambda = [\lambda_1, \lambda_2, \lambda_3] \longrightarrow \|\hat{C}(\lambda)\|_F $$
#
# - **λ** represents a combination of preferences among objectives.
# - **∥Ĉ(λ)∥_F** measures the structural variability of the optimal solutions associated with these preferences.
#
#  The surrogate model will serve as a fast predictor, aiding the global algorithm to more efficiently explore the multi-objective space.

# %% [markdown]
# ### Choice of the DTLZ2 benchmark problem
# The choice of the benchmark problem **DTLZ2** is motivated by its widespread adoption in literature for testing multi-objective evolutionary algorithms (MOEAs), due to its regular Pareto front and easy scalability to multiple objectives [1] . Parameter selection (e.g., number of λ samples and generation method) follows established recommendations [2][3], facilitating easier evaluation based on known behavior of the DTLZ2 problem [4].
#
# References:
# [1] R. Cheng, Y. Jin, M. Olhofer and B. Sendhoff, "A Reference Vector Guided Evolutionary Algorithm for Many-Objective Optimization," in IEEE Transactions on Evolutionary Computation, vol. 20, no. 5, pp. 773-791, Oct. 2016, doi: 10.1109/TEVC.2016.2519378.
# [2] Y. Yuan, H. Xu, B. Wang and X. Yao, "A New Dominance Relation-Based Evolutionary Algorithm for Many-Objective Optimization," in IEEE Transactions on Evolutionary Computation, vol. 20, no. 1, pp. 16-37, Feb. 2016, doi: 10.1109/TEVC.2015.2420112.
# [3] H. Wu, Y. Jin, K. Gao, J. Ding and R. Cheng, "Surrogate-Assisted Evolutionary Multi-Objective Optimization of Medium-Scale Problems by Random Grouping and Sparse Gaussian Modeling," in IEEE Transactions on Emerging Topics in Computational Intelligence, vol. 8, no. 5, pp. 3263-3278, Oct. 2024, doi: 10.1109/TETCI.2024.3372378.
# [4] Wang, X.; Jin, Y. Knowledge Transfer Based on Particle Filters for Multi-Objective Optimization. Math. Comput. Appl. 2023, 28, 14. https://doi.org/10.3390/mca28010014

# %%
from pymoo.problems.many import DTLZ2
import numpy as np
np.random.seed(42)
# Problem Definition
n_obj = 3
k = 20
n_vars = n_obj + k - 1

problem = DTLZ2(n_var=n_vars, n_obj=n_obj)

# %% [markdown]
# ### Using random.rand to generate λ vectors

# %%
from scipy.optimize import minimize
import pandas as pd
from sklearn.preprocessing import normalize

# Step 1: Generation of λ vectors
# Random user preference vectors (λ), each with length 3, are generated. Each λ vector sums to 1, representing normalized preferences among different objectives

n_lambda = 1000
lambda_vectors = np.random.rand(n_lambda, n_obj)
lambda_vectors = normalize(lambda_vectors, norm='l1', axis=1)

# Define scalarized objective function based on λ preferences
def scalarized_objective(x, lam):
    f = problem.evaluate(np.array([x]))[0]
    return np.dot(lam, f)

# Find optimal solutions x* for each λ preference
x_star_list = []

for lam in lambda_vectors:
    res = minimize(scalarized_objective,
                   x0=np.full(n_vars, 0.5),
                   args=(lam,),
                   method='L-BFGS-B',
                   bounds=[(0.0, 1.0)] * n_vars)
    x_star_list.append(res.x)
x_star_array = np.array(x_star_list)

# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.neighbors import NearestNeighbors
from pymoo.problems.many import DTLZ2
from pymoo.util.reference_direction import UniformReferenceDirectionFactory

n_obj = 3
n_vars = 22
problem = DTLZ2(n_var=n_vars, n_obj=n_obj)

n_lambda_core = 700
n_lambda_edge = 300
alpha_core = [1.0] * n_obj
alpha_edge = [0.2] * n_obj

lambda_core = np.random.dirichlet(alpha_core, size=n_lambda_core)
lambda_edge = np.random.dirichlet(alpha_edge, size=n_lambda_edge)
lambda_vectors = np.vstack([lambda_core, lambda_edge])
lambda_types = ['core'] * n_lambda_core + ['edge'] * n_lambda_edge
def scalarized_objective(x, lam):
    f = problem.evaluate(np.array([x]))[0]
    return np.dot(lam, f)
x_star_list = []
for lam in lambda_vectors:
    res = minimize(scalarized_objective,
                   x0=np.full(n_vars, 0.5),
                   args=(lam,),
                   method='L-BFGS-B',
                   bounds=[(0.0, 1.0)] * n_vars)
    x_star_list.append(res.x)
x_star_array = np.array(x_star_list)
k_neighbors = 10
jitter_std = 1e-2
C_matrices = []
frob_norms = []
variances = []
P_vectors = []

nn = NearestNeighbors(n_neighbors=k_neighbors).fit(lambda_vectors)
neighbor_indices = nn.kneighbors(lambda_vectors, return_distance=False)

for idxs in neighbor_indices:
    X_local = x_star_array[idxs] + np.random.normal(0, jitter_std, size=(k_neighbors, n_vars))
    X_local = StandardScaler().fit_transform(X_local)

    C = np.cov(X_local.T)
    C += np.eye(C.shape[0]) * 1e-8  # regolarizzazione
    C_matrices.append(C)

    frob = np.linalg.norm(C, ord='fro')
    frob_norms.append(frob)

    var = np.var(X_local, axis=0)
    variances.append(var)

    P = np.linalg.cholesky(C)
    P_vectors.append(P[np.tril_indices_from(P)])
data_dict = {f"lambda_{i+1}": lambda_vectors[:, i] for i in range(n_obj)}
data_dict["frob_norm"] = frob_norms
for i in range(n_vars):
    data_dict[f"x_star_{i+1}"] = x_star_array[:, i]
    data_dict[f"var_x_star_{i+1}"] = [v[i] for v in variances]
for i in range(len(P_vectors[0])):
    data_dict[f"P_vec_{i+1}"] = [p[i] for p in P_vectors]
data_dict["lambda_type"] = lambda_types
data_dict["batch_id"] = np.arange(len(lambda_vectors))

dataset = pd.DataFrame(data_dict)
dataset.dropna(inplace=True)

dataset.to_csv("dtlz2_surrogate_dataset_enhanced.csv", index=False)
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(lambda_vectors[:,0], lambda_vectors[:,1], lambda_vectors[:,2], c='blue', alpha=0.5)
ax.set_xlabel('λ1')
ax.set_ylabel('λ2')
ax.set_zlabel('λ3')
plt.title('Distribuzione dei vettori λ nel simplex')
plt.show()

# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt

# --- Configurazione problema ---
n_obj = 3
n_vars = 22
problem = DTLZ2(n_var=n_vars, n_obj=n_obj)
jitter_std = 1e-2
k_neighbors = 10

# --- Funzione obiettivo scalarizzata ---
def scalarized_objective(x, lam):
    f = problem.evaluate(np.array([x]))[0]
    return np.dot(lam, f)

# --- Caricamento dataset esistente ---
dataset = pd.read_csv("dtlz2_surrogate_dataset_extended_updated.csv")
x_star_array = dataset[[col for col in dataset.columns if col.startswith("x_star_")]].values

# --- Espansione ai vertici e bordi ---
lambda_extreme = np.eye(n_obj)
lambda_border = []
for i in range(n_obj):
    lam = np.random.rand(50, n_obj)
    lam[:, i] = np.random.uniform(0.9, 1.0, 50)
    lambda_border.append(normalize(lam, norm='l1', axis=1))
lambda_border = np.vstack(lambda_border)

lambda_new = np.vstack([lambda_extreme, lambda_border])

# --- Calcolo x*(lambda) ---
x_star_new, frob_norms, variances, P_vectors = [], [], [], []

nn = NearestNeighbors(n_neighbors=k_neighbors).fit(lambda_new)
neighbor_indices = nn.kneighbors(lambda_new, return_distance=False)

for lam, idxs in zip(lambda_new, neighbor_indices):
    res = minimize(scalarized_objective, x0=np.full(n_vars, 0.5), args=(lam,), method='L-BFGS-B', bounds=[(0.0, 1.0)] * n_vars)
    x_star = res.x
    x_star_new.append(x_star)

    X_local = np.array([x_star] + [x_star_array[i] for i in idxs])
    X_local += np.random.normal(0, jitter_std, X_local.shape)
    X_local = StandardScaler().fit_transform(X_local)

    C = np.cov(X_local.T) + np.eye(n_vars) * 1e-8
    frob = np.linalg.norm(C, ord='fro')
    frob_norms.append(frob)
    var = np.var(X_local, axis=0)
    variances.append(var)
    P = np.linalg.cholesky(C)
    P_vectors.append(P[np.tril_indices_from(P)])

# --- Costruzione dataframe ---
data_dict = {f"lambda_{i+1}": lambda_new[:, i] for i in range(n_obj)}
data_dict["frob_norm"] = frob_norms
for i in range(n_vars):
    data_dict[f"x_star_{i+1}"] = [x[i] for x in x_star_new]
    data_dict[f"var_x_star_{i+1}"] = [v[i] for v in variances]
for i in range(len(P_vectors[0])):
    data_dict[f"P_vec_{i+1}"] = [p[i] for p in P_vectors]
data_dict["source"] = ["extreme"] * len(lambda_new)

new_df = pd.DataFrame(data_dict)
dataset_combined = pd.concat([dataset, new_df], ignore_index=True)

# --- Log1p e Scaling Frobenius ---
dataset_combined = dataset_combined[(dataset_combined['frob_norm'] > 0.01) & (dataset_combined['frob_norm'] < 8)]
dataset_combined['frob_log'] = np.log1p(dataset_combined['frob_norm'])
dataset_combined['frob_scaled'] = StandardScaler().fit_transform(dataset_combined[['frob_log']])

# --- Salvataggio ---
dataset_combined.to_csv("dtlz2_dataset_expanded_scaled.csv", index=False)
print("✅ Dataset espanso salvato come 'dtlz2_dataset_expanded_scaled.csv'")

# --- Plot varianza per dimensione ---
plt.figure(figsize=(12, 4))
var_matrix = dataset_combined[[col for col in dataset_combined.columns if col.startswith("var_x_star_")]].values
mean_var = np.mean(var_matrix, axis=0)
plt.bar(range(1, n_vars + 1), mean_var)
plt.title("Media della varianza per dimensione di x*(λ)")
plt.xlabel("Indice della variabile decisionale")
plt.ylabel("Varianza media")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ✅ Dataset espanso salvato come 'dtlz2_dataset_expanded_scaled.csv'

# %% [markdown]
# #### Using UniformReferenceDirectionFactory to generate λ vectors

# %%
# Using UniformReferenceDirectionFactory to generate λ vectors
from pymoo.util.reference_direction import UniformReferenceDirectionFactory

lambda_grid = UniformReferenceDirectionFactory(n_dim=n_obj, n_points=n_lambda).do()


def scalarized_objective(x, lam):
    f = problem.evaluate(np.array([x]))[0]
    return np.dot(lam, f)


x_star_list = []

for lam in lambda_grid: 
    res = minimize(scalarized_objective,
                   x0=np.full(n_vars, 0.5),
                   args=(lam,),
                   method='L-BFGS-B',
                   bounds=[(0.0, 1.0)] * n_vars)
    x_star_list.append(res.x)

x_star_array = np.array(x_star_list)

# %% [markdown]
# ### Using random.dirichlet to generate λ vectors

# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
n_lambda = 1000
alpha = [1.0] * n_obj
jitter_std = 1e-2
lambda_vectors = np.random.dirichlet(alpha, size=n_lambda)

print(f"✅ Numero finale di λ: {len(lambda_vectors)}")

# === Funzione scalarizzata ===
def scalarized_objective(x, lam):
    f = problem.evaluate(np.array([x]))[0]
    return np.dot(lam, f)

# === Ottimizzazione per ottenere x*(λ) ===
x_star_list = []
for lam in lambda_vectors:
    res = minimize(scalarized_objective,
                   x0=np.full(n_vars, 0.5),
                   args=(lam,),
                   method='L-BFGS-B',
                   bounds=[(0.0, 1.0)] * n_vars)
    x_star_list.append(res.x)

x_star_array = np.array(x_star_list)
# Out:
# ✅ Numero finale di λ: 1000

# %% [markdown]
# ## Step 2: Covariance matrix calculation and its Frobenius norm

# %%
from sklearn.preprocessing import StandardScaler

# Step 2: Covariance matrix calculation and its Frobenius norm
# For each λ vector, results from the scalarized multi-objective problem are simulated or computed. Then, the covariance matrix of local optimal solutions and its Frobenius norm (indicating local variability) are estimated.

window_size = 10
C_matrices = []
frob_norms = []
variances = []
P_vectors = []

for i in range(n_lambda):
    start = max(0, i - window_size // 2)
    end = min(n_lambda, i + window_size // 2 + 1)
    X_local = x_star_array[start:end]

    scaler = StandardScaler()
    X_local = scaler.fit_transform(X_local)

    C = np.cov(X_local.T)
    C += np.eye(C.shape[0]) * 1e-8  # regularization
    C_matrices.append(C)

    frob = np.linalg.norm(C, ord='fro')
    frob_norms.append(frob)

    var = np.var(X_local, axis=0)
    variances.append(var)

    P = np.linalg.cholesky(C)
    P_vectors.append(P[np.tril_indices_from(P)])

# %% [markdown]
# #### Calculate covariance matrices for each λ vector using k nearest neighbors

# %%
from sklearn.neighbors import NearestNeighbors
k_neighbors = 10
C_matrices = []
frob_norms = []
variances = []
P_vectors = []

nn = NearestNeighbors(n_neighbors=k_neighbors).fit(lambda_vectors)
neighbor_indices = nn.kneighbors(lambda_vectors, return_distance=False)

for idxs in neighbor_indices:
    X_local = x_star_array[idxs] + np.random.normal(0, jitter_std, size=(k_neighbors, n_vars))
    X_local = StandardScaler().fit_transform(X_local)

    C = np.cov(X_local.T)
    C += np.eye(C.shape[0]) * 1e-8
    C_matrices.append(C)

    frob = np.linalg.norm(C, ord='fro')
    frob_norms.append(frob)

    var = np.var(X_local, axis=0)
    variances.append(var)

    P = np.linalg.cholesky(C)
    P_vectors.append(P[np.tril_indices_from(P)])

# %%
# Step 3: Creating the final dataset
# Combine generated λ vectors and corresponding Frobenius norms into a DataFrame for training the surrogate model.

data_dict = {f"lambda_{i+1}": lambda_vectors[:, i] for i in range(n_obj)}
data_dict["frob_norm"] = frob_norms
for i in range(n_vars):
    data_dict[f"x_star_{i+1}"] = x_star_array[:, i]
    data_dict[f"var_x_star_{i+1}"] = [v[i] for v in variances]
for i in range(len(P_vectors[0])):
    data_dict[f"P_vec_{i+1}"] = [p[i] for p in P_vectors]
data_dict["source"] = ["original"] * len(lambda_vectors)

# %%
#Step 3: Creating the final dataset with additional variables
data_dict = {f"lambda_{i+1}": lambda_vectors[:, i] for i in range(n_obj)}
data_dict["frob_norm"] = frob_norms

# Aggiungi i vettori x* (soluzioni ottime)
for i in range(n_vars):
    data_dict[f"x_star_{i+1}"] = [x[i] for x in x_star_array]

# Aggiungi le varianze locali
for i in range(n_vars):
    data_dict[f"var_x_star_{i+1}"] = [var[i] for var in variances]

# Aggiungi i coefficienti della decomposizione di Cholesky
for i in range(len(P_vectors[0])):
    data_dict[f"P_vec_{i+1}"] = [P[i] for P in P_vectors]

# Creazione del dataset finale
dataset = pd.DataFrame(data_dict)
dataset.to_csv("dtlz2_extended.csv", index=False)

# %%
# Generate additional λ samples close to the simplex borders for extended coverage
window_size = 10
n_new_samples = 50
lambda_borders = []
for i in range(3):
    lam = np.random.rand(n_new_samples, 3)
    lam[:, i] = np.random.uniform(0.9, 1.0, n_new_samples)
    lambda_borders.append(normalize(lam, norm='l1', axis=1))
lambda_borders = np.vstack(lambda_borders)

existing_lambdas = lambda_vectors
filtered_lambda_borders = np.array([lam for lam in lambda_borders if not np.any(np.all(np.abs(existing_lambdas - lam) < 1e-5, axis=1))])

new_frob_norms, new_x_star, new_variances, new_P_vectors = [], [], [], []
for lam in filtered_lambda_borders:
    res = minimize(scalarized_objective, x0=np.full(n_vars, 0.5), args=(lam,), method='L-BFGS-B', bounds=[(0.0, 1.0)] * n_vars)
    x_opt = res.x
    new_x_star.append(x_opt)
    if len(new_x_star) >= 2:
        X_local = StandardScaler().fit_transform(np.array(new_x_star[-window_size:]))
        C = np.cov(X_local.T) + np.eye(n_vars) * 1e-8
        new_frob_norms.append(np.linalg.norm(C, ord='fro'))
        new_variances.append(np.var(X_local, axis=0))
        P = np.linalg.cholesky(C)
        new_P_vectors.append(P[np.tril_indices_from(P)])
    else:
        new_frob_norms.append(np.nan)
        new_variances.append(np.full(n_vars, np.nan))
        new_P_vectors.append(np.full((n_vars * (n_vars + 1)) // 2, np.nan))
        new_data_dict = {f"lambda_{i+1}": filtered_lambda_borders[:, i] for i in range(3)}
new_data_dict["frob_norm"] = new_frob_norms
for i in range(n_vars):
    new_data_dict[f"x_star_{i+1}"] = [x[i] for x in new_x_star]
    new_data_dict[f"var_x_star_{i+1}"] = [v[i] for v in new_variances]
for i in range(len(new_P_vectors[0])):
    new_data_dict[f"P_vec_{i+1}"] = [p[i] for p in new_P_vectors]
new_data_dict["source"] = ["border"] * len(filtered_lambda_borders)

new_df = pd.DataFrame(new_data_dict)
dataset = pd.DataFrame(data_dict)
updated_dataset = pd.concat([dataset, new_df], ignore_index=True)
updated_dataset.to_csv("loss.csv", index=False)

# %% [markdown]
# ### PCA on P_vec vectors and balancing

# %%
pvec_cols = df.filter(like="P_vec_").columns
pca_result = PCA(n_components=n_pca_components).fit_transform(df[pvec_cols])
for i in range(n_pca_components):
    df[f"PCA_{i+1}"] = pca_result[:, i]

df["f_bin"] = pd.qcut(df["frob_norm"], q=10, labels=False)
per_bin = 100
balanced = (
    df.groupby("f_bin")
      .apply(lambda g: g.sample(per_bin, replace=len(g) < per_bin, random_state=42))
      .reset_index(drop=True)
      .drop(columns="f_bin")
)


balanced.to_csv("dtlz2_dataset_pca_balanced.csv", index=False)
print("✅ Dataset finale salvato: dtlz2_dataset_knn_pca.csv")

# %% [markdown]
# ## Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot distribution of Frobenius norm
plt.figure(figsize=(8, 5))
sns.histplot(updated_dataset["frob_norm"], bins=50, kde=True)
plt.title("Frobenius Norm Distribution")
plt.xlabel("‖C(λ)‖_F")
plt.ylabel("Frequenza")
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot heatmap: λ₁ vs λ₂ vs Frobenius norm
updated_dataset["lambda_1_bin"] = pd.cut(updated_dataset["lambda_1"], bins=20)
updated_dataset["lambda_2_bin"] = pd.cut(updated_dataset["lambda_2"], bins=20)
heatmap_data = updated_dataset.pivot_table(index="lambda_1_bin", columns="lambda_2_bin", values="frob_norm", aggfunc="mean")

plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, cmap="viridis")
plt.title("Heatmap: λ₁ vs λ₂ vs ‖C(λ)‖_F")
plt.xlabel("λ₂ (binned)")
plt.ylabel("λ₁ (binned)")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\aless\AppData\Local\Temp\ipykernel_23016\3927540443.py:17: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   heatmap_data = updated_dataset.pivot_table(index="lambda_1_bin", columns="lambda_2_bin", values="frob_norm", aggfunc="mean")

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

# Caricamento del dataset
df = pd.read_csv("dtlz2.csv")

# Creazione del grafico 3D
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot 3D
sc = ax.scatter(df["lambda_1"], df["lambda_2"], df["lambda_3"], c=df["frob_norm"], cmap="viridis", alpha=0.8)

# Aggiunta della barra colore
cbar = plt.colorbar(sc, ax=ax, pad=0.1)
cbar.set_label("‖C(λ)‖_F")

# Etichette degli assi
ax.set_xlabel("λ₁")
ax.set_ylabel("λ₂")
ax.set_zlabel("λ₃")
ax.set_title("Relation λ₁, λ₂, λ₃ and ‖C(λ)‖_F")

plt.tight_layout()
plt.show()

# %%
import pandas as pd


df = pd.read_csv("dtlz2.csv")


num_rows = df.shape[0]

stats = df[["lambda_1", "lambda_2", "lambda_3", "frob_norm"]].describe()


missing_values = df[["lambda_1", "lambda_2", "lambda_3", "frob_norm"]].isnull().sum()

print(f"Numerosity  dataset: {num_rows}")
print("\n Statistic Analysis:")
print(stats)
print("\n Missing values :")
print(missing_values)

import seaborn as sns
sns.histplot(dataset["frob_norm"], bins=50, kde=True)
print("Range frob_norm:", dataset["frob_norm"].min(), dataset["frob_norm"].max())
print("Std frob_norm:", dataset["frob_norm"].std())
print("Correlation λ1 vs frob_norm:", dataset["lambda_1"].corr(dataset["frob_norm"]))
print("Correlation λ2 vs frob_norm:", dataset["lambda_2"].corr(dataset["frob_norm"]))
print("Correlation λ3 vs frob_norm:", dataset["lambda_3"].corr(dataset["frob_norm"]))
# Out:
# Numerosity  dataset: 1150
#
#  Statistic Analysis:
#           lambda_1     lambda_2     lambda_3    frob_norm
# count  1150.000000  1150.000000  1150.000000  1149.000000
# mean      0.340880     0.321107     0.338013     8.491223
# std       0.226365     0.224616     0.227260     2.615002
# min       0.000061     0.000182     0.000726     1.111111
# 25%       0.152006     0.128505     0.150956     9.225406
# 50%       0.309292     0.286987     0.315439     9.422129
# 75%       0.494042     0.472316     0.487986     9.622147
# max       0.984869     0.990673     0.989993    10.473545
#
#  Missing values :
# lambda_1     0
# lambda_2     0
# lambda_3     0
# frob_norm    1
# dtype: int64
# Range frob_norm: 8.807052732157768 10.473544557743573
# Std frob_norm: 0.25788474242623616
# Correlation λ1 vs frob_norm: 0.001622433987823865
# Correlation λ2 vs frob_norm: 0.031339052276179356
# Correlation λ3 vs frob_norm: -0.032642278755981594
